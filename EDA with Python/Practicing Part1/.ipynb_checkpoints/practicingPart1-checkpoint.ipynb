# %%
import pandas as pd

# %%
file_name = "dataset/Pokemon.csv"

# %%
df = pd.read_csv(file_name)
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.shape
# Out:
# (800, 13)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
#Counts each Type 1 Pokemon on dataset 
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
#Counts each Type 1 Pokemon on dataset
df['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Rock        14
# Water       14
# Ice         14
# Ghost       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
#Counts how many legendary Pokemon has in dataset
df['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
#Counts most common speed on Pokemon
df['Speed'].value_counts()
# Out:
# 50     46
# 60     44
# 70     37
# 65     36
# 30     35
#        ..
# 82      1
# 103     1
# 87      1
# 88      1
# 180     1
# Name: Speed, Length: 108, dtype: int64

# %%
#Counts the number of Pokemon per each generation
df['Generation'].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
#Counts the HP Pokemon
df['HP'].value_counts()
# Out:
# 60     67
# 50     63
# 70     57
# 65     46
# 75     43
#        ..
# 97      1
# 99      1
# 101     1
# 104     1
# 255     1
# Name: HP, Length: 94, dtype: int64

# %%
#Returns the lowest HP Pokemon
df.sort_values('HP')
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 487  439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Return ascending sort Pokemon Attack
df.sort_values('Attack')
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 488  440                  Happiny   Normal       NaN    220  100       5
# 121  113                  Chansey   Normal       NaN    450  250       5
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 261  242                  Blissey   Normal       NaN    540  255      10
# 139  129                 Magikarp    Water       NaN    200   20      10
# ..   ...                      ...      ...       ...    ...  ...     ...
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Ascending sort Type1 Flying Pokemon
df[df['Type 1']=='Flying'].sort_values('Sp. Atk')
# Out:
#        #                     Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 790  714                   Noibat  Flying  Dragon    245  40      30       35
# 791  715                  Noivern  Flying  Dragon    535  85      70       80
# 703  641    TornadusTherian Forme  Flying     NaN    580  79     100       80
# 702  641  TornadusIncarnate Forme  Flying     NaN    580  79     115       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# 703      110       90    121           5       True
# 702      125       80    111           5       True

# %%
#Counts Type 2 Fairy Pokemon has Generation 2
df[df['Type 2']=='Fairy'].value_counts(df['Generation']==2)
# Out:
# Generation
# False    20
# True      3
# dtype: int64
